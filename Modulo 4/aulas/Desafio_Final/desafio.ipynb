# %%
import pandas as pd
df = pd.read_csv('Salary.csv')

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
x_sal = df[['YearsExperience']]
y_sal = df[['Salary']]

# %%
from sklearn.preprocessing import StandardScaler
standar_scaler =  StandardScaler()

x_sal = standar_scaler.fit_transform(x_sal)
# y_sal = standar_scaler.fit_transform(y_sal)

# %%
x_sal
# Out:
# array([[-1.46039873],
#        [-1.40432198],
#        [-1.34824523],
#        [-1.20805336],
#        [-1.15197661],
#        [-0.955708  ],
#        [-0.92766962],
#        [-0.87159288],
#        [-0.87159288],
#        [-0.73140101],
#        [-0.67532426],
#        [-0.64728589],
#        [-0.64728589],
#        [-0.61924751],
#        [-0.50709402],
#        [-0.39494052],
#        [-0.33886377],
#        [-0.28278703],
#        [-0.11455678],
#        [-0.08651841],
#        [ 0.13778858],
#        [ 0.2219037 ],
#        [ 0.44621069],
#        [ 0.53032581],
#        [ 0.67051768],
#        [ 0.7546328 ],
#        [ 0.89482467],
#        [ 0.92286305],
#        [ 1.11913166],
#        [ 1.17520841],
#        [ 1.37147703],
#        [ 1.45559215],
#        [ 1.67989914],
#        [ 1.84812938],
#        [ 2.01635962]])

# %%
y_sal
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872
# 30  127345
# 31  126756
# 32  128765
# 33  135675
# 34  139465

# %%
from sklearn.model_selection import train_test_split
x_sal_treinamento, x_sal_teste, y_sal_treinamento, y_sal_teste = train_test_split(x_sal, y_sal, test_size = 0.25, random_state = 0)

# %%
from sklearn.neural_network import MLPClassifier
rede_neural_credit = MLPClassifier(max_iter = 1000, verbose = True, tol=0.0000100,  learning_rate_init= 0.001,
                                  hidden_layer_sizes =(20,100))
rede_neural_credit.fit(x_sal_treinamento, y_sal_treinamento)
# Out:
# c:\Users\GAMERX\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1102: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 3.25858339
# Iteration 2, loss = 3.24955770
# Iteration 3, loss = 3.24077475
# Iteration 4, loss = 3.23220952
# Iteration 5, loss = 3.22382871
# Iteration 6, loss = 3.21563542
# Iteration 7, loss = 3.20750251
# Iteration 8, loss = 3.19938228
# Iteration 9, loss = 3.19135139
# Iteration 10, loss = 3.18326737
# Iteration 11, loss = 3.17515134
# Iteration 12, loss = 3.16697529
# Iteration 13, loss = 3.15872110
# Iteration 14, loss = 3.15038785
# Iteration 15, loss = 3.14207158
# Iteration 16, loss = 3.13372838
# Iteration 17, loss = 3.12537286
# Iteration 18, loss = 3.11700402
# Iteration 19, loss = 3.10858415
# Iteration 20, loss = 3.10017480
# ...

# %%
import requests
import json

url = 'https://as5jmctylk.execute-api.us-east-1.amazonaws.com/default/demo_forecast'

data = {"jonas": 5,
        "marta": 2,
        "miguel": 11.4
        }

requests = requests.post(url, data=json.dumps(data))

response = requests.json()
