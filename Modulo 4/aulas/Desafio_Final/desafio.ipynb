# %%
import pandas as pd
df = pd.read_csv('Salary.csv')

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.shape
# Out:
# (35, 2)

# %%
x_sal = df[['YearsExperience']]
y_sal = df[['Salary']]

# %%
med_years = x_sal.mean()
med_years
# Out:
# YearsExperience    6.308571
# dtype: float64

# %%
med_salary = y_sal.mean()
med_salary
# Out:
# Salary    83945.6
# dtype: float64

# %%
df['Razao'] = df['Salary'] / df['YearsExperience']

display(df)

df = df.sort_values('Razao',ascending=False)
# Out:
#     YearsExperience  Salary         Razao
# 0               1.1   39343  35766.363636
# 1               1.3   46205  35542.307692
# 2               1.5   37731  25154.000000
# 3               2.0   43525  21762.500000
# 4               2.2   39891  18132.272727
# 5               2.9   56642  19531.724138
# 6               3.0   60150  20050.000000
# 7               3.2   54445  17014.062500
# 8               3.2   64445  20139.062500
# 9               3.7   57189  15456.486486
# 10              3.9   63218  16209.743590
# 11              4.0   55794  13948.500000
# 12              4.0   56957  14239.250000
# 13              4.1   57081  13922.195122
# 14              4.5   61111  13580.222222
# 15              4.9   67938  13864.897959
# 16              5.1   66029  12946.862745
# 17              5.3   83088  15676.981132
# 18              5.9   81363  13790.338983
# 19              6.0   93940  15656.666667
# 20              6.8   91738  13490.882353
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot
fig, ax = plt.subplots()
ax.plot(x_sal, y_sal, linewidth=2.0)
plt.show()

# %%
import requests
import json

url = 'https://as5jmctylk.execute-api.us-east-1.amazonaws.com/default/demo_forecast'

data = {"jonas": 5,
        "marta": 2,
        "miguel": 11.4,
        "Nome": 15,
        "Nome": 0,
        }

requests = requests.post(url, data=json.dumps(data))

response = requests.json()
print(response)
# Out:
# {'jonas': 72519.23, 'marta': 46323.41, 'miguel': 128403.65, 'Nome': 28859.53}
